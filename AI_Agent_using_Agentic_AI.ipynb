# %% [markdown]
# # AI Agent using Agentic AI

# %%
import yfinance as yf
import pandas as pd
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import random
from collections import deque

# %%
# define symbol and time

symbol = "AAPL"
start_date = "2020-01-01"
end_date = "2025-02-24"

# %%
# Data Download

df = yf.download(symbol, start=start_date, end=end_date)
# Out:
# YF.download() has changed argument auto_adjust default to True
# [*********************100%***********************]  1 of 1 completed

# %% [markdown]
# # Feature Engineering

# %%
df['SMA_5'] = df['Close'].rolling(window=5).mean()
df['SMA_20'] = df['Close'].rolling(window=20).mean()
df['Returns'] = df['Close'].pct_change()

# %%
df.dropna(inplace=True)
df.reset_index(drop=True, inplace=True)

# %% [markdown]
# # Defining Acion space

# %%
Actions = {0: "HOLD", 1: "BUY", 2: "SELL"}

# %%
def get_state(df, index):
    return np.array([
        float(df.loc[index, 'Close']),
        float(df.loc[index, 'SMA_5']),
        float(df.loc[index, 'SMA_20']),
        float(df.loc[index, 'Returns']),
    ])

# %% [markdown]
# # Building Environment for Agent

# %%
class TradingEnvironment:
    def __init__(self, df):
        self.df = df
        self.initial_balance = 10000
        self.balance = self.initial_balance
        self.holdings = 0
        self.index = 0

    def reset(self):
        self.balance = self.initial_balance
        self.holdings = 0
        self.index = 0
        return get_state(self.df, self.index)

    def step(self, action):
        price = float(self.df.loc[self.index, 'Close'])
        reward = 0

        if action == 1 and self.balance >= price:
            self.holdings = self.balance // price
            self.balance -= self.holdings * price
        elif action == 2 and self.holdings > 0:
            self.balance += self.holdings * price
            self.holdings = 0
        self.index += 1
        done = self.index >= len(self.df) - 1
        if done :
            reward = self.balance - self.initial_balance

        next_state = get_state(self.df, self.index) if not done else None
        return next_state, reward, done, {}

# %% [markdown]
# # Deep QNetwork

# %%
class DQN(nn.Module):
    def __init__(self, state_size, action_size):
        super(DQN, self).__init__()
        self.fc1 = nn.Linear(state_size, 64)
        self.fc2 = nn.Linear(64, 64)
        self.fc3 = nn.Linear(64, action_size)
    def forward(self, x):
        x = torch.relu(self.fc1(x))
        x = torch.relu(self.fc2(x))
        return self.fc3(x)

# %% [markdown]
# # DQN Agent

# %%
class DQNAgent:
    def __init__(self, state_size, action_size):
        self.state_size = state_size
        self.action_size = action_size
        self.memory = deque(maxlen = 2000)
        self.gamma = 0.95
        self.epsilon = 1.0
        self.epsilon_min = 0.995
        self.epsilon_decay = 0.995
        self.learning_rate = 0.001
        self.model = DQN(state_size, action_size)
        self.optimizer = optim.Adam(self.model.parameters(), lr=self.learning_rate)
        self.criterion = nn.MSELoss()

    def remember(self, state, action, reward, next_state, done):
        self.memory.append((state, action, reward, next_state, done))

    def act(self, state):
        if random.uniform(0, 1) < self.epsilon:
            return random.choice(list(Actions.keys()))
        state = torch.FloatTensor(state).unsqueeze(0)
        with torch.no_grad():
            q_values = self.model(state)
        return torch.argmax(q_values).item()
    def replay(self, batch_size):
        if len(self.memory) < batch_size:
            return
        minibatch = random.sample(self.memory, batch_size)

        for state, action, reward, next_state, done in minibatch:
            target = reward
            if not done:
                next_state_tensor = torch.FloatTensor(next_state).unsqueeze(0)
                target += self.gamma * torch.max(self.model(next_state_tensor)).item()

            state_tensor = torch.FloatTensor(state).unsqueeze(0)
            target_tensor = self.model(state_tensor).clone().detach()
            target_tensor[0][action] = target
            self.optimizer.zero_grad()
            output = self.model(state_tensor)
            loss = self.criterion(output, target_tensor)
            loss.backward()
            self.optimizer.step()

        if self.epsilon > self.epsilon_min:
            self.epsilon *= self.epsilon_decay

# %% [markdown]
# # Training

# %%
env = TradingEnvironment(df)
agent = DQNAgent(state_size=4, action_size=3)
batch_size = 32
episodes = 500
total_rewards = []

for episode in range(episodes):
    state = env.reset()
    done = False
    total_reward = 0

    while not done:
        action = agent.act(state)
        next_state, reward, done, _ = env.step(action)
        agent.remember(state, action, reward, next_state, done)
        state = next_state
        total_reward += reward

    agent.replay(batch_size)
    total_rewards.append(total_reward)
    print(f"Episode {episode+1}/{episodes}, Total Reward: {total_reward}")

print("Training Complete!")
# Out:
# <ipython-input-8-435ab85a210d>:3: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   float(df.loc[index, 'Close']),
# <ipython-input-8-435ab85a210d>:4: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   float(df.loc[index, 'SMA_5']),
# <ipython-input-8-435ab85a210d>:5: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   float(df.loc[index, 'SMA_20']),
# <ipython-input-8-435ab85a210d>:6: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   float(df.loc[index, 'Returns']),
# <ipython-input-9-716ac2eb592e>:16: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   price = float(self.df.loc[self.index, 'Close'])
# Episode 1/500, Total Reward: -9939.841484069824
# Episode 2/500, Total Reward: -9992.113983154297
# Episode 3/500, Total Reward: -9919.872188568115
# Episode 4/500, Total Reward: 9375.639671325684
# Episode 5/500, Total Reward: -9784.97509765625
# Episode 6/500, Total Reward: -9805.311935424805
# Episode 7/500, Total Reward: -9845.643013000488
# Episode 8/500, Total Reward: -9870.549018859863
# Episode 9/500, Total Reward: 6640.612163543701
# Episode 10/500, Total Reward: -9861.947647094727
# Episode 11/500, Total Reward: 2516.5684089660645
# Episode 12/500, Total Reward: -9988.677139282227
# Episode 13/500, Total Reward: -9850.955074310303
# Episode 14/500, Total Reward: -9875.424404144287
# Episode 15/500, Total Reward: -9843.125370025635
# Episode 16/500, Total Reward: -9815.525001525879
# Episode 17/500, Total Reward: -9884.95157623291
# Episode 18/500, Total Reward: -9828.735778808594
# Episode 19/500, Total Reward: -9940.198749542236
# Episode 20/500, Total Reward: -9927.276191711426
# Episode 21/500, Total Reward: -9929.627799987793
# Episode 22/500, Total Reward: 15889.749111175537
# Episode 23/500, Total Reward: -9843.170028686523
# Episode 24/500, Total Reward: -9801.052303314209
# Episode 25/500, Total Reward: -9883.18274307251
# Episode 26/500, Total Reward: 7212.128849029541
# Episode 27/500, Total Reward: -9894.110836029053
# Episode 28/500, Total Reward: -9970.038360595703
# Episode 29/500, Total Reward: 2971.825206756592
# Episode 30/500, Total Reward: -9750.011657714844
# Episode 31/500, Total Reward: -9937.033142089844
# Episode 32/500, Total Reward: -9796.83288192749
# Episode 33/500, Total Reward: 18076.196964263916
# Episode 34/500, Total Reward: -9824.92274093628
# Episode 35/500, Total Reward: -9936.975177764893
# Episode 36/500, Total Reward: -9779.039001464844
# Episode 37/500, Total Reward: -9801.690979003906
# Episode 38/500, Total Reward: -9875.799556732178
# Episode 39/500, Total Reward: -9892.524166107178
# Episode 40/500, Total Reward: -9931.194206237793
# Episode 41/500, Total Reward: -9803.669776916504
# Episode 42/500, Total Reward: -9821.634227752686
# Episode 43/500, Total Reward: -9844.7631149292
# Episode 44/500, Total Reward: -9910.280853271484
# Episode 45/500, Total Reward: -9795.930522918701
# Episode 46/500, Total Reward: -9819.350154876709
# Episode 47/500, Total Reward: -9820.943286895752
# Episode 48/500, Total Reward: -9866.52082824707
# Episode 49/500, Total Reward: -9919.829330444336
# Episode 50/500, Total Reward: -9931.65930557251
# Episode 51/500, Total Reward: 13987.446964263916
# Episode 52/500, Total Reward: -9927.876399993896
# Episode 53/500, Total Reward: -9839.389419555664
# Episode 54/500, Total Reward: -9909.61209487915
# Episode 55/500, Total Reward: -9846.430408477783
# Episode 56/500, Total Reward: -9988.09852218628
# Episode 57/500, Total Reward: -9932.160049438477
# Episode 58/500, Total Reward: -9889.740356445312
# Episode 59/500, Total Reward: -9884.768043518066
# Episode 60/500, Total Reward: -9848.44938659668
# Episode 61/500, Total Reward: -9780.203437805176
# Episode 62/500, Total Reward: -9891.45389175415
# Episode 63/500, Total Reward: 9898.0669631958
# Episode 64/500, Total Reward: -9920.216983795166
# Episode 65/500, Total Reward: -9917.022556304932
# Episode 66/500, Total Reward: -9772.68930053711
# Episode 67/500, Total Reward: -9829.265518188477
# Episode 68/500, Total Reward: -9915.75686264038
# Episode 69/500, Total Reward: 8957.873859405518
# Episode 70/500, Total Reward: -9864.383861541748
# Episode 71/500, Total Reward: -9738.835037231445
# Episode 72/500, Total Reward: -9728.984455108643
# Episode 73/500, Total Reward: -9818.435398101807
# Episode 74/500, Total Reward: -9777.837196350098
# Episode 75/500, Total Reward: -9873.534866333008
# Episode 76/500, Total Reward: -9907.722759246826
# Episode 77/500, Total Reward: -9858.5481300354
# Episode 78/500, Total Reward: -9763.87654876709
# Episode 79/500, Total Reward: -9822.874561309814
# Episode 80/500, Total Reward: -9768.547527313232
# Episode 81/500, Total Reward: -9937.039199829102
# Episode 82/500, Total Reward: -9874.215232849121
# Episode 83/500, Total Reward: -9991.826656341553
# Episode 84/500, Total Reward: -9926.079627990723
# Episode 85/500, Total Reward: 16795.242710113525
# Episode 86/500, Total Reward: -9824.721992492676
# Episode 87/500, Total Reward: -9870.163051605225
# Episode 88/500, Total Reward: -9812.700096130371
# Episode 89/500, Total Reward: -9861.568305969238
# Episode 90/500, Total Reward: -9880.020195007324
# Episode 91/500, Total Reward: -9889.279312133789
# Episode 92/500, Total Reward: -9930.716510772705
# Episode 93/500, Total Reward: -9827.28723526001
# Episode 94/500, Total Reward: -9872.95736694336
# Episode 95/500, Total Reward: -9892.687320709229
# Episode 96/500, Total Reward: -9838.820358276367
# Episode 97/500, Total Reward: -9934.962985992432
# Episode 98/500, Total Reward: -9995.894569396973
# Episode 99/500, Total Reward: 15677.173126220703
# Episode 100/500, Total Reward: -9866.619918823242
# Episode 101/500, Total Reward: -9878.443328857422
# Episode 102/500, Total Reward: -9785.873275756836
# Episode 103/500, Total Reward: -9912.526233673096
# Episode 104/500, Total Reward: -9872.512397766113
# Episode 105/500, Total Reward: 3740.2981719970703
# Episode 106/500, Total Reward: -9797.189949035645
# Episode 107/500, Total Reward: 8700.920867919922
# Episode 108/500, Total Reward: -9843.710437774658
# Episode 109/500, Total Reward: -9874.305759429932
# Episode 110/500, Total Reward: -9825.110218048096
# Episode 111/500, Total Reward: -9951.203311920166
# Episode 112/500, Total Reward: -9804.22110748291
# Episode 113/500, Total Reward: -9773.954418182373
# Episode 114/500, Total Reward: -9828.097946166992
# Episode 115/500, Total Reward: -9775.466369628906
# Episode 116/500, Total Reward: -9812.409832000732
# Episode 117/500, Total Reward: -9854.678535461426
# Episode 118/500, Total Reward: -9827.07145690918
# Episode 119/500, Total Reward: -9904.929218292236
# Episode 120/500, Total Reward: -9798.189777374268
# Episode 121/500, Total Reward: -9934.379600524902
# Episode 122/500, Total Reward: -9842.20195388794
# Episode 123/500, Total Reward: -9800.446598052979
# Episode 124/500, Total Reward: -9926.475017547607
# Episode 125/500, Total Reward: -9874.211708068848
# Episode 126/500, Total Reward: -9939.318099975586
# Episode 127/500, Total Reward: -9933.943614959717
# Episode 128/500, Total Reward: -9868.473667144775
# Episode 129/500, Total Reward: -9923.727771759033
# Episode 130/500, Total Reward: -9781.248565673828
# Episode 131/500, Total Reward: -9860.736042022705
# Episode 132/500, Total Reward: -9795.012748718262
# Episode 133/500, Total Reward: -9773.611999511719
# Episode 134/500, Total Reward: 4144.004550933838
# Episode 135/500, Total Reward: -9760.408920288086
# Episode 136/500, Total Reward: -9915.44560623169
# Episode 137/500, Total Reward: -9913.5004196167
# Episode 138/500, Total Reward: -9891.260196685791
# Episode 139/500, Total Reward: -9875.695808410645
# Episode 140/500, Total Reward: -9761.018367767334
# Episode 141/500, Total Reward: -9856.280513763428
# Episode 142/500, Total Reward: -9884.00006866455
# Episode 143/500, Total Reward: -9983.901996612549
# Episode 144/500, Total Reward: -9871.404251098633
# Episode 145/500, Total Reward: -9800.841499328613
# Episode 146/500, Total Reward: 11462.075790405273
# Episode 147/500, Total Reward: -9871.140319824219
# Episode 148/500, Total Reward: -9752.275886535645
# Episode 149/500, Total Reward: 10340.411609649658
# Episode 150/500, Total Reward: -9831.278244018555
# Episode 151/500, Total Reward: -9861.579055786133
# Episode 152/500, Total Reward: -9976.853378295898
# Episode 153/500, Total Reward: -9907.302013397217
# Episode 154/500, Total Reward: -9909.134048461914
# Episode 155/500, Total Reward: -9930.259223937988
# Episode 156/500, Total Reward: -9921.291637420654
# Episode 157/500, Total Reward: -9885.741966247559
# Episode 158/500, Total Reward: -9859.815845489502
# Episode 159/500, Total Reward: -9808.749267578125
# Episode 160/500, Total Reward: -9800.868255615234
# Episode 161/500, Total Reward: 4867.386962890625
# Episode 162/500, Total Reward: -9840.855251312256
# Episode 163/500, Total Reward: -9879.881351470947
# Episode 164/500, Total Reward: -9829.791320800781
# Episode 165/500, Total Reward: -9767.839427947998
# Episode 166/500, Total Reward: -9832.5419921875
# Episode 167/500, Total Reward: -9820.301696777344
# Episode 168/500, Total Reward: 6546.159870147705
# Episode 169/500, Total Reward: -9904.03158569336
# Episode 170/500, Total Reward: -9786.857303619385
# Episode 171/500, Total Reward: 731.9754219055176
# Episode 172/500, Total Reward: 14446.015571594238
# Episode 173/500, Total Reward: -9729.37688446045
# Episode 174/500, Total Reward: -1442.6617698669434
# Episode 175/500, Total Reward: -9930.359909057617
# Episode 176/500, Total Reward: -9991.423023223877
# Episode 177/500, Total Reward: -9867.063888549805
# Episode 178/500, Total Reward: -9778.553176879883
# Episode 179/500, Total Reward: 6774.870693206787
# Episode 180/500, Total Reward: 8908.650043487549
# Episode 181/500, Total Reward: -9871.035873413086
# Episode 182/500, Total Reward: 6486.0607261657715
# Episode 183/500, Total Reward: -9829.78600692749
# Episode 184/500, Total Reward: -9930.986324310303
# Episode 185/500, Total Reward: -9773.368553161621
# Episode 186/500, Total Reward: -9758.32092666626
# Episode 187/500, Total Reward: -9793.718112945557
# Episode 188/500, Total Reward: -9824.065822601318
# Episode 189/500, Total Reward: -9867.466804504395
# Episode 190/500, Total Reward: 28956.826789855957
# Episode 191/500, Total Reward: -9880.076343536377
# Episode 192/500, Total Reward: -9949.023937225342
# Episode 193/500, Total Reward: -9864.021095275879
# Episode 194/500, Total Reward: 14896.007381439209
# Episode 195/500, Total Reward: -9860.251846313477
# Episode 196/500, Total Reward: -9827.933418273926
# Episode 197/500, Total Reward: -9805.483985900879
# Episode 198/500, Total Reward: -9882.761615753174
# Episode 199/500, Total Reward: -9892.290977478027
# Episode 200/500, Total Reward: 13931.106929779053
# Episode 201/500, Total Reward: -9932.075233459473
# Episode 202/500, Total Reward: -9886.919960021973
# Episode 203/500, Total Reward: -9796.411170959473
# Episode 204/500, Total Reward: -9825.806797027588
# Episode 205/500, Total Reward: -9800.15843963623
# Episode 206/500, Total Reward: -9789.56731414795
# Episode 207/500, Total Reward: -9933.077461242676
# Episode 208/500, Total Reward: -9841.258693695068
# Episode 209/500, Total Reward: -9939.350563049316
# Episode 210/500, Total Reward: -9862.495094299316
# Episode 211/500, Total Reward: -9929.901142120361
# Episode 212/500, Total Reward: -9917.813133239746
# Episode 213/500, Total Reward: -9977.033405303955
# Episode 214/500, Total Reward: -9882.122764587402
# Episode 215/500, Total Reward: -9858.343486785889
# Episode 216/500, Total Reward: 6388.073001861572
# Episode 217/500, Total Reward: -9894.52237701416
# Episode 218/500, Total Reward: -9854.87018585205
# Episode 219/500, Total Reward: -9875.866195678711
# Episode 220/500, Total Reward: -9893.286808013916
# Episode 221/500, Total Reward: -9810.178009033203
# Episode 222/500, Total Reward: -9927.685497283936
# Episode 223/500, Total Reward: -9938.545593261719
# Episode 224/500, Total Reward: -9941.513668060303
# Episode 225/500, Total Reward: -9916.454975128174
# Episode 226/500, Total Reward: -9836.587398529053
# Episode 227/500, Total Reward: 25761.055839538574
# Episode 228/500, Total Reward: -9871.012683868408
# Episode 229/500, Total Reward: -9841.704750061035
# Episode 230/500, Total Reward: -9982.039051055908
# Episode 231/500, Total Reward: 6040.9403076171875
# Episode 232/500, Total Reward: -9882.944328308105
# Episode 233/500, Total Reward: -9792.432201385498
# Episode 234/500, Total Reward: -9912.879474639893
# Episode 235/500, Total Reward: -9770.522636413574
# Episode 236/500, Total Reward: -9820.470993041992
# Episode 237/500, Total Reward: -9876.291625976562
# Episode 238/500, Total Reward: -9935.351726531982
# Episode 239/500, Total Reward: -9762.316844940186
# Episode 240/500, Total Reward: -9890.826248168945
# Episode 241/500, Total Reward: -9866.34870147705
# Episode 242/500, Total Reward: -9858.982730865479
# Episode 243/500, Total Reward: -9862.46146774292
# Episode 244/500, Total Reward: 18132.99146270752
# Episode 245/500, Total Reward: -9879.403785705566
# Episode 246/500, Total Reward: -9925.779972076416
# Episode 247/500, Total Reward: 9488.300930023193
# Episode 248/500, Total Reward: -9871.700138092041
# Episode 249/500, Total Reward: -9906.96397781372
# Episode 250/500, Total Reward: -9804.535278320312
# Episode 251/500, Total Reward: 2524.4076652526855
# Episode 252/500, Total Reward: -9848.369625091553
# Episode 253/500, Total Reward: -9779.220798492432
# Episode 254/500, Total Reward: -9940.221950531006
# Episode 255/500, Total Reward: -9900.872951507568
# Episode 256/500, Total Reward: -9829.112201690674
# Episode 257/500, Total Reward: -9944.377746582031
# Episode 258/500, Total Reward: -9838.640266418457
# Episode 259/500, Total Reward: -9907.974090576172
# Episode 260/500, Total Reward: -9774.532375335693
# Episode 261/500, Total Reward: -9875.452693939209
# Episode 262/500, Total Reward: -9836.463550567627
# Episode 263/500, Total Reward: -9815.125434875488
# Episode 264/500, Total Reward: -9923.623165130615
# Episode 265/500, Total Reward: -9852.039031982422
# Episode 266/500, Total Reward: -9841.928970336914
# Episode 267/500, Total Reward: -9754.98000717163
# Episode 268/500, Total Reward: -9984.859977722168
# Episode 269/500, Total Reward: 9303.283184051514
# Episode 270/500, Total Reward: -9860.037654876709
# Episode 271/500, Total Reward: -9955.397651672363
# Episode 272/500, Total Reward: -9932.903343200684
# Episode 273/500, Total Reward: -9831.19214630127
# Episode 274/500, Total Reward: -9859.799263000488
# Episode 275/500, Total Reward: -9876.90595626831
# Episode 276/500, Total Reward: -9822.898513793945
# Episode 277/500, Total Reward: -9784.555213928223
# Episode 278/500, Total Reward: -9889.886013031006
# Episode 279/500, Total Reward: -9906.746532440186
# Episode 280/500, Total Reward: -9930.11943435669
# Episode 281/500, Total Reward: -9810.919147491455
# Episode 282/500, Total Reward: -9906.958801269531
# Episode 283/500, Total Reward: -9794.238441467285
# Episode 284/500, Total Reward: -9887.859813690186
# Episode 285/500, Total Reward: -9938.265174865723
# Episode 286/500, Total Reward: -9775.445980072021
# Episode 287/500, Total Reward: -9895.520645141602
# Episode 288/500, Total Reward: -9873.389072418213
# Episode 289/500, Total Reward: -9861.50175857544
# Episode 290/500, Total Reward: -9840.591800689697
# Episode 291/500, Total Reward: -9859.60457611084
# Episode 292/500, Total Reward: -9927.663257598877
# Episode 293/500, Total Reward: 11677.723529815674
# Episode 294/500, Total Reward: -9892.398223876953
# Episode 295/500, Total Reward: -9924.281391143799
# Episode 296/500, Total Reward: 9652.935745239258
# Episode 297/500, Total Reward: -9878.827083587646
# Episode 298/500, Total Reward: -9805.692737579346
# Episode 299/500, Total Reward: -9872.788917541504
# Episode 300/500, Total Reward: -9870.350643157959
# Episode 301/500, Total Reward: -9884.947277069092
# Episode 302/500, Total Reward: -9929.68095779419
# Episode 303/500, Total Reward: -9954.360439300537
# Episode 304/500, Total Reward: 12773.581115722656
# Episode 305/500, Total Reward: 9838.790355682373
# Episode 306/500, Total Reward: -9892.847854614258
# Episode 307/500, Total Reward: -9941.410652160645
# Episode 308/500, Total Reward: -9982.86922454834
# Episode 309/500, Total Reward: -9930.301151275635
# Episode 310/500, Total Reward: -9921.40587234497
# Episode 311/500, Total Reward: -9825.882797241211
# Episode 312/500, Total Reward: -9893.264122009277
# Episode 313/500, Total Reward: -9884.307514190674
# Episode 314/500, Total Reward: -9853.762191772461
# Episode 315/500, Total Reward: -9838.53409576416
# Episode 316/500, Total Reward: -9885.401344299316
# Episode 317/500, Total Reward: -9931.886421203613
# Episode 318/500, Total Reward: -9920.186222076416
# Episode 319/500, Total Reward: -9987.821235656738
# Episode 320/500, Total Reward: -9928.948612213135
# Episode 321/500, Total Reward: -9843.001293182373
# Episode 322/500, Total Reward: -9903.84281539917
# Episode 323/500, Total Reward: 3611.9593811035156
# Episode 324/500, Total Reward: -9859.596565246582
# Episode 325/500, Total Reward: 2752.5987663269043
# Episode 326/500, Total Reward: -9874.572616577148
# Episode 327/500, Total Reward: -9875.060424804688
# Episode 328/500, Total Reward: -9876.048892974854
# Episode 329/500, Total Reward: -9967.875175476074
# Episode 330/500, Total Reward: -9998.331451416016
# Episode 331/500, Total Reward: -9821.471004486084
# Episode 332/500, Total Reward: -9881.800971984863
# Episode 333/500, Total Reward: -9876.353115081787
# Episode 334/500, Total Reward: -9868.66590499878
# Episode 335/500, Total Reward: -9873.890434265137
# Episode 336/500, Total Reward: 5968.752490997314
# Episode 337/500, Total Reward: -9725.575542449951
# Episode 338/500, Total Reward: -9932.735218048096
# Episode 339/500, Total Reward: -9807.473133087158
# Episode 340/500, Total Reward: -9998.157684326172
# Episode 341/500, Total Reward: 14708.969367980957
# Episode 342/500, Total Reward: -9767.523643493652
# Episode 343/500, Total Reward: -9868.28483581543
# Episode 344/500, Total Reward: -9751.47501373291
# Episode 345/500, Total Reward: -9813.706809997559
# Episode 346/500, Total Reward: -9886.414791107178
# Episode 347/500, Total Reward: -9802.985912322998
# Episode 348/500, Total Reward: -9864.979640960693
# Episode 349/500, Total Reward: -9805.748756408691
# Episode 350/500, Total Reward: -9811.866729736328
# Episode 351/500, Total Reward: -9876.764484405518
# Episode 352/500, Total Reward: -9877.64295578003
# Episode 353/500, Total Reward: 6471.035808563232
# Episode 354/500, Total Reward: -9921.04636001587
# Episode 355/500, Total Reward: -9903.829696655273
# Episode 356/500, Total Reward: -9803.213989257812
# Episode 357/500, Total Reward: -9791.143043518066
# Episode 358/500, Total Reward: -9874.109985351562
# Episode 359/500, Total Reward: -9960.967288970947
# Episode 360/500, Total Reward: -9905.020984649658
# Episode 361/500, Total Reward: -9965.124439239502
# Episode 362/500, Total Reward: -9878.290481567383
# Episode 363/500, Total Reward: -9936.692840576172
# Episode 364/500, Total Reward: -9791.913471221924
# Episode 365/500, Total Reward: 12449.331104278564
# Episode 366/500, Total Reward: -9886.2611618042
# Episode 367/500, Total Reward: -9856.809246063232
# Episode 368/500, Total Reward: 2855.841896057129
# Episode 369/500, Total Reward: -9892.659461975098
# Episode 370/500, Total Reward: -9963.314502716064
# Episode 371/500, Total Reward: -9811.245456695557
# Episode 372/500, Total Reward: -9930.681716918945
# Episode 373/500, Total Reward: -9887.191272735596
# Episode 374/500, Total Reward: -9844.692672729492
# Episode 375/500, Total Reward: -9736.349109649658
# Episode 376/500, Total Reward: -9882.168643951416
# Episode 377/500, Total Reward: -9853.597904205322
# Episode 378/500, Total Reward: -9883.291000366211
# Episode 379/500, Total Reward: -9875.623287200928
# Episode 380/500, Total Reward: -9890.60962677002
# Episode 381/500, Total Reward: -9937.646244049072
# Episode 382/500, Total Reward: -9873.818717956543
# Episode 383/500, Total Reward: 13243.106029510498
# Episode 384/500, Total Reward: -9858.049259185791
# Episode 385/500, Total Reward: -9942.340843200684
# Episode 386/500, Total Reward: -9843.161506652832
# Episode 387/500, Total Reward: -9936.364406585693
# Episode 388/500, Total Reward: -9918.643043518066
# Episode 389/500, Total Reward: -9819.919158935547
# Episode 390/500, Total Reward: -9810.71091079712
# Episode 391/500, Total Reward: -9913.770160675049
# Episode 392/500, Total Reward: -9968.979969024658
# Episode 393/500, Total Reward: -9888.490245819092
# Episode 394/500, Total Reward: -9912.218315124512
# Episode 395/500, Total Reward: -9905.87417602539
# Episode 396/500, Total Reward: -9813.410060882568
# Episode 397/500, Total Reward: 43813.45031738281
# Episode 398/500, Total Reward: -9790.23514175415
# Episode 399/500, Total Reward: 7569.150390625
# Episode 400/500, Total Reward: -9871.36039352417
# Episode 401/500, Total Reward: 5966.392665863037
# Episode 402/500, Total Reward: -9789.970039367676
# Episode 403/500, Total Reward: 6208.145889282227
# Episode 404/500, Total Reward: -9842.088088989258
# Episode 405/500, Total Reward: -9759.21863937378
# Episode 406/500, Total Reward: 10478.303867340088
# Episode 407/500, Total Reward: -9866.382431030273
# Episode 408/500, Total Reward: -9810.826042175293
# Episode 409/500, Total Reward: -9816.7280960083
# Episode 410/500, Total Reward: -9812.136688232422
# Episode 411/500, Total Reward: -9878.254844665527
# Episode 412/500, Total Reward: -9937.613021850586
# Episode 413/500, Total Reward: 6465.50203704834
# Episode 414/500, Total Reward: -9761.305381774902
# Episode 415/500, Total Reward: -9877.504829406738
# Episode 416/500, Total Reward: -9766.904239654541
# Episode 417/500, Total Reward: 16319.751300811768
# Episode 418/500, Total Reward: 2046.6846923828125
# Episode 419/500, Total Reward: -9888.382266998291
# Episode 420/500, Total Reward: -9788.011302947998
# Episode 421/500, Total Reward: -9839.534580230713
# Episode 422/500, Total Reward: -9927.884284973145
# Episode 423/500, Total Reward: -9845.39476776123
# Episode 424/500, Total Reward: -9766.30704498291
# Episode 425/500, Total Reward: -9815.959384918213
# Episode 426/500, Total Reward: -9774.177375793457
# Episode 427/500, Total Reward: -9815.697563171387
# Episode 428/500, Total Reward: -9808.514743804932
# Episode 429/500, Total Reward: -9854.832775115967
# Episode 430/500, Total Reward: -9775.240135192871
# Episode 431/500, Total Reward: -9866.74775314331
# Episode 432/500, Total Reward: -9903.704471588135
# Episode 433/500, Total Reward: -9773.927337646484
# Episode 434/500, Total Reward: -9885.353351593018
# Episode 435/500, Total Reward: -9852.829113006592
# Episode 436/500, Total Reward: -9883.542697906494
# Episode 437/500, Total Reward: 6749.359210968018
# Episode 438/500, Total Reward: -9873.295917510986
# Episode 439/500, Total Reward: -9746.556922912598
# Episode 440/500, Total Reward: -9858.958110809326
# Episode 441/500, Total Reward: -9855.059104919434
# Episode 442/500, Total Reward: -9868.281322479248
# Episode 443/500, Total Reward: 4631.661331176758
# Episode 444/500, Total Reward: -9947.629955291748
# Episode 445/500, Total Reward: 10939.271991729736
# Episode 446/500, Total Reward: -9995.74305343628
# Episode 447/500, Total Reward: -9815.882823944092
# Episode 448/500, Total Reward: -9995.130321502686
# Episode 449/500, Total Reward: 6398.458908081055
# Episode 450/500, Total Reward: -9844.75191116333
# Episode 451/500, Total Reward: -9781.372241973877
# Episode 452/500, Total Reward: -9784.272731781006
# Episode 453/500, Total Reward: -9936.514945983887
# Episode 454/500, Total Reward: -9826.308109283447
# Episode 455/500, Total Reward: -9757.0475730896
# Episode 456/500, Total Reward: -9810.275959014893
# Episode 457/500, Total Reward: -9846.573177337646
# Episode 458/500, Total Reward: 6352.606052398682
# Episode 459/500, Total Reward: -9752.246768951416
# Episode 460/500, Total Reward: -9707.739376068115
# Episode 461/500, Total Reward: -9841.490390777588
# Episode 462/500, Total Reward: -9935.971530914307
# Episode 463/500, Total Reward: -9855.17727279663
# Episode 464/500, Total Reward: -9833.186798095703
# Episode 465/500, Total Reward: 15194.324398040771
# Episode 466/500, Total Reward: -9902.353652954102
# Episode 467/500, Total Reward: -9858.018257141113
# Episode 468/500, Total Reward: -9976.376564025879
# Episode 469/500, Total Reward: -9820.326389312744
# Episode 470/500, Total Reward: -9936.143863677979
# Episode 471/500, Total Reward: -9876.742485046387
# Episode 472/500, Total Reward: 10767.688243865967
# Episode 473/500, Total Reward: -9780.65414428711
# Episode 474/500, Total Reward: -9828.433151245117
# Episode 475/500, Total Reward: -9936.148929595947
# Episode 476/500, Total Reward: -850.2213134765625
# Episode 477/500, Total Reward: -9879.173793792725
# Episode 478/500, Total Reward: -9823.456405639648
# Episode 479/500, Total Reward: -9879.908641815186
# Episode 480/500, Total Reward: 3884.882164001465
# Episode 481/500, Total Reward: -9873.178691864014
# Episode 482/500, Total Reward: 7378.913558959961
# Episode 483/500, Total Reward: -9810.626502990723
# Episode 484/500, Total Reward: -9858.780738830566
# Episode 485/500, Total Reward: -9784.23821258545
# Episode 486/500, Total Reward: -9839.990398406982
# Episode 487/500, Total Reward: -9934.854782104492
# Episode 488/500, Total Reward: -9933.559387207031
# Episode 489/500, Total Reward: -9936.16039276123
# Episode 490/500, Total Reward: -9881.857734680176
# Episode 491/500, Total Reward: -9891.95315170288
# Episode 492/500, Total Reward: -9869.038177490234
# Episode 493/500, Total Reward: -9942.249221801758
# Episode 494/500, Total Reward: -9860.593727111816
# Episode 495/500, Total Reward: -9809.63606262207
# Episode 496/500, Total Reward: 41442.84411621094
# Episode 497/500, Total Reward: -9899.526016235352
# Episode 498/500, Total Reward: -9775.042808532715
# Episode 499/500, Total Reward: -9842.603248596191
# Episode 500/500, Total Reward: -9938.024845123291
# Training Complete!

# %%
test_env = TradingEnvironment(df)
state = test_env.reset()
done = False

while not done:
    action = agent.act(state)
    next_state, reward, done, _ = test_env.step(action)
    state = next_state if next_state is not None else state

final_balance = test_env.balance
profit = final_balance - test_env.initial_balance
print(f"Final Balance after testing: ${final_balance:.2f}")
print(f"Total Profit: ${profit:.2f}")
# Out:
# <ipython-input-8-435ab85a210d>:3: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   float(df.loc[index, 'Close']),
# <ipython-input-8-435ab85a210d>:4: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   float(df.loc[index, 'SMA_5']),
# <ipython-input-8-435ab85a210d>:5: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   float(df.loc[index, 'SMA_20']),
# <ipython-input-8-435ab85a210d>:6: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   float(df.loc[index, 'Returns']),
# <ipython-input-9-716ac2eb592e>:16: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   price = float(self.df.loc[self.index, 'Close'])
# Final Balance after testing: $149.46
# Total Profit: $-9850.54
